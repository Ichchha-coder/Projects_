# %% [markdown]
# <a href="https://colab.research.google.com/github/Ichchha-coder/Projects_/blob/main/Data_cleaning_and_processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df_1 = pd.read_csv("Power_Test_C11(Sheet1).csv", encoding='windows-1252')

# %%
df_1.shape
# Out:
# (14, 47)

# %%
df_1.columns
# Out:
# Index(['Id', 'Start time', 'Completion time', 'Email', 'Name', 'Total points',
#        'Quiz feedback', 'Grade posted time', 'Full Name', 'Points - Full Name',
#        'Feedback - Full Name', 'Section : C11/C12',
#        'Points - Section : C11/C12', 'Feedback - Section : C11/C12',
#        'What is the value of 3! ?\n', 'Points - What is the value of 3! ?\n',
#        'Feedback - What is the value of 3! ?\n',
#        'In which case the relation is equivalent?\n',
#        'Points - In which case the relation is equivalent?\n',
#        'Feedback - In which case the relation is equivalent?\n',
#        'If f(x-1)= x -2, What is the value of f(-1)?\n',
#        'Points - If f(x-1)= x -2, What is the value of f(-1)?\n',
#        'Feedback - If f(x-1)= x -2, What is the value of f(-1)?\n',
#        'What is the meaning of bi in binomial distribution?\n',
#        'Points - What is the meaning of bi in binomial distribution?\n',
# ...

# %%
df_1 = df_1[['Full Name', 'Section : C11/C12', 'Total points']]

# %%
df_1.head()
# Out:
#        Full Name Section : C11/C12  Total points
# 0  Ajar Shrestha               C11             7
# 1  Sandhya Dumre               C11             9
# 2     Riya Joshi               C11             6
# 3   Aditya Raut                C11             7
# 4  Manisha Shah                C11             9

# %%
df_1.shape
# Out:
# (14, 3)

# %%
df_1.columns = ['Full_Name', 'Section', 'Score']

# %%
df_1['Remarks'] = ''

# %%
df_1.head(15)
# Out:
#           Full_Name Section  Score Remarks
# 0     Ajar Shrestha     C11      7
# 1     Sandhya Dumre     C11      9
# 2        Riya Joshi     C11      6
# 3      Aditya Raut      C11      7
# 4     Manisha Shah      C11      9
# 5        Alina B.k.     C11      6
# 6       Raunit Giri     C11      7
# 7   Aayush Shrestha     C11      7
# 8        Milan Lama    Lama      7
# 9     Kritee Khadka     C11      8
# 10     Sabal Sharma     C11      8
# 11    Luckey Lawaju     C11      8
# 12       Nigesh Pun     C11      5
# 13    Sadique Akbar     c11      4

# %%
df_1.loc[df_1['Full_Name'] == 'Milan Lama', 'Section'] = 'C11'

# %%
df_1.head(15)
# Out:
#           Full_Name Section  Score Remarks
# 0     Ajar Shrestha     C11      7
# 1     Sandhya Dumre     C11      9
# 2        Riya Joshi     C11      6
# 3      Aditya Raut      C11      7
# 4     Manisha Shah      C11      9
# 5        Alina B.k.     C11      6
# 6       Raunit Giri     C11      7
# 7   Aayush Shrestha     C11      7
# 8        Milan Lama     C11      7
# 9     Kritee Khadka     C11      8
# 10     Sabal Sharma     C11      8
# 11    Luckey Lawaju     C11      8
# 12       Nigesh Pun     C11      5
# 13    Sadique Akbar     c11      4

# %%
df_1.loc[df_1['Full_Name'] == 'Sadique Akbar', 'Section'] = 'C11'

# %%
import pandas as pd

# New rows to be added (including absent students with Score = 0 and Remarks = 'Absent')
new_data = pd.DataFrame([
    {'Full_Name': 'Ashika Bhusal', 'Section': 'C11', 'Score': 6, 'Remarks': ''},
    {'Full_Name': 'Anju Yadav', 'Section': 'C11', 'Score': 3, 'Remarks': ''},
    {'Full_Name': 'Himal Pnadey', 'Section': 'C11', 'Score': 4, 'Remarks': ''},
    {'Full_Name': 'Om Prakash Yadav', 'Section': 'C11', 'Score': 0, 'Remarks': ''},
    {'Full_Name': 'Roshan Jaiswal', 'Section': 'C11', 'Score': 0, 'Remarks': ''}
])

# Add to existing df_1
df_1 = pd.concat([df_1, new_data], ignore_index=True)

# %%
df_1.loc[df_1['Full_Name'] == 'Himal Pnadey', 'Full_Name'] = 'Himal Pandey'

# %%
df_1.shape
# Out:
# (19, 4)

# %%
df_1.to_csv("C11.csv", index=False)

# %%
df_2 = pd.read_csv("Power_Test_C12(Sheet1).csv", encoding='windows-1252')

# %%
df_2.shape
# Out:
# (15, 47)

# %%
df_2.columns
# Out:
# Index(['Id', 'Start time', 'Completion time', 'Email', 'Name', 'Total points',
#        'Quiz feedback', 'Grade posted time', 'Full_Name', 'Points - Full_Name',
#        'Feedback - Full_Name', 'Section: C11/C12', 'Points - Section: C11/C12',
#        'Feedback - Section: C11/C12',
#        'Which of the following best describes the flowchart?',
#        'Points - Which of the following best describes the flowchart?',
#        'Feedback - Which of the following best describes the flowchart?',
#        'If f(x) = x-3 , what is the value of f(3)?',
#        'Points - If f(x) = x-3 , what is the value of f(3)?',
#        'Feedback - If f(x) = x-3 , what is the value of f(3)?',
#        'What is the value of 0! ?', 'Points - What is the value of 0! ?',
#        'Feedback - What is the value of 0! ?',
#        'Please select the best answer,regarding permutation and combination.\n',
#        'Points - Please select the best answer,regarding permutation and combination.\n',
# ...

# %%
df_2 = df_2[['Full_Name', 'Section: C11/C12', 'Total points']]

# %%
df_2.columns = ['Full_Name', 'Section', 'Score']

# %%
df_2.shape
# Out:
# (15, 3)

# %%
new_row_1 = pd.DataFrame([{
    'Full_Name': 'Nitesh Raut',
    'Section': 'C12',
    'Score': 0
}])

df_2 = pd.concat([df_2, new_row_1], ignore_index=True)

# %%
df_2.shape
# Out:
# (16, 3)

# %%
df_2.to_csv("C12.csv", index=False)
